# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
vgsales = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/vgsales.csv")

# %%
vgsales.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
print(vgsales.head())
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
print(vgsales.describe())
# Out:
#                Rank      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254      0.264667      0.146659      0.077774      0.048070
# std     4791.853933      0.816683      0.505350      0.309292      0.188588
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4151.250000      0.000000      0.000000      0.000000      0.000000
# 50%     8300.500000      0.080000      0.020000      0.000000      0.010000
# 75%    12449.750000      0.240000      0.110000      0.040000      0.040000
# max    16600.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16596.000000
# mean       0.537498
# std        1.555113
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %%
print(vgsales.isnull())
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False  False     False  False  False      False     False     False
# 1      False  False     False  False  False      False     False     False
# 2      False  False     False  False  False      False     False     False
# 3      False  False     False  False  False      False     False     False
# 4      False  False     False  False  False      False     False     False
# ...      ...    ...       ...    ...    ...        ...       ...       ...
# 16593  False  False     False  False  False      False     False     False
# 16594  False  False     False  False  False      False     False     False
# 16595  False  False     False  False  False      False     False     False
# 16596  False  False     False  False  False      False     False     False
# 16597  False  False     False  False  False      False     False     False
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
data.tail()
# Out:
#         Rank                                              Name Platform  Year  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
#           Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16593  Platform       Kemco      0.01      0.00       0.0          0.0
# 16594   Shooter  Infogrames      0.01      0.00       0.0          0.0
# 16595    Racing  Activision      0.00      0.00       0.0          0.0
# 16596    Puzzle    7G//AMES      0.00      0.01       0.0          0.0
# 16597  Platform     Wanadoo      0.01      0.00       0.0          0.0
#
#        Global_Sales
# 16593          0.01
# 16594          0.01
# ...

# %%
vgsales.shape
# Out:
# (16598, 11)

# %%
vgsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  object
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16596 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
labels = [ 'will sports', 'Super mario bros', 'mario kart will', 'pokemon red/pokrmonblue']


plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(11,11))
plt.pie(list(vgsales['Genre'].value_counts()), autopct='%1.1f%%', labels=labels, wedgeprops={'edgecolor':'black'})
plt.title('Most Popular Genres in Video Games')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-cdeebde68dbd> in <cell line: 6>()
#       4 plt.style.use('fivethirtyeight')
#       5 fig = plt.figure(figsize=(11,11))
# ----> 6 plt.pie(list(vgsales['Genre'].value_counts()), autopct='%1.1f%%', labels=labels, wedgeprops={'edgecolor':'black'})
#       7 plt.title('Most Popular Genres in Video Games')
#       8 plt.tight_layout()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
# ...

# %%
from collections import Counter
a = list(['vgsales'])
letter_counts = Counter(a)
d = pd.DataFrame.from_dict(letter_counts, orient='index')


d.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Plot a histogram for all the variables

# %%
vgsales.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Rank'}>,
#         <Axes: title={'center': 'NA_Sales'}>],
#        [<Axes: title={'center': 'EU_Sales'}>,
#         <Axes: title={'center': 'JP_Sales'}>],
#        [<Axes: title={'center': 'Other_Sales'}>,
#         <Axes: title={'center': 'Global_Sales'}>]], dtype=object)

# %%
filterr = (vgsales['Global_Sales']==vgsales['Global_Sales'].max())
vgsales['Name'][filterr]
# Out:
# 0    Wii Sports
# Name: Name, dtype: object

# %%
sns.pairplot(vgsales)
