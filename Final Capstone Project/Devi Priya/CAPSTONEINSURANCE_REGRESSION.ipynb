# %%
import pandas as pd
data=pd.read_csv("/content/train.csv")

# %%
data.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   1    A    B    A    B    A    A    A    A    B  ...  0.718367  0.335060
# 1   2    A    B    A    A    A    A    A    A    B  ...  0.438917  0.436585
# 2   5    A    B    A    A    B    A    A    A    B  ...  0.289648  0.315545
# 3  10    B    B    A    B    A    A    A    A    B  ...  0.440945  0.391128
# 4  11    A    B    A    B    A    A    A    A    B  ...  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14     loss
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  2213.18
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  1283.60
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  3005.09
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642   939.85
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  2763.85
#
# [5 rows x 132 columns]

# %%
data.tail()
# Out:
#         id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6  \
# 2828  9049    A    B    A    A    B    A    A    A    B  ...  0.818930
# 2829  9057    A    B    A    A    A    A    A    A    B  ...  0.764704
# 2830  9058    A    B    A    B    B    A    A    A    B  ...  0.902605
# 2831  9059    A    B    A    A    A    A    A    A    B  ...  0.853309
# 2832  9063    A    A    B    A    A    B    A    A    A  ...       NaN
#
#          cont7    cont8    cont9   cont10    cont11    cont12    cont13  \
# 2828  0.479806  0.96024  0.86299  0.83510  0.739860  0.772574  0.810511
# 2829  0.844865  0.53642  0.55648  0.64056  0.705501  0.692256  0.758902
# 2830  0.529361  0.96693  0.93383  0.83510  0.644013  0.908179  0.864518
# 2831  0.590091  0.83275  0.91644  0.81923  0.935094  0.935432  0.846403
# 2832       NaN      NaN      NaN      NaN       NaN       NaN       NaN
#
#         cont14      loss
# 2828  0.739898  13809.55
# 2829  0.817953  12690.39
# 2830  0.681520  16503.63
# ...

# %%
data.isna().sum()
# Out:
# id        0
# cat1      0
# cat2      0
# cat3      0
# cat4      0
#          ..
# cont11    1
# cont12    1
# cont13    1
# cont14    1
# loss      1
# Length: 132, dtype: int64

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# id        0
# cat1      0
# cat2      0
# cat3      0
# cat4      0
#          ..
# cont11    0
# cont12    0
# cont13    0
# cont14    0
# loss      0
# Length: 132, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2832 entries, 0 to 2831
# Columns: 132 entries, id to loss
# dtypes: float64(15), int64(1), object(116)
# memory usage: 2.9+ MB

# %%
category = []
for column in data.columns:
  if data[column].dtype =="object":
    category.append(column)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder().fit(data[category])
data[category] = oe.transform(data[category])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2832 entries, 0 to 2831
# Columns: 132 entries, id to loss
# dtypes: float64(131), int64(1)
# memory usage: 2.9 MB

# %%
data.describe()
# Out:
#                 id         cat1         cat2         cat3         cat4  \
# count  2832.000000  2832.000000  2832.000000  2832.000000  2832.000000
# mean   4558.614054     0.241879     0.433969     0.056497     0.317090
# std    2607.961020     0.428297     0.495708     0.230920     0.465425
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2286.750000     0.000000     0.000000     0.000000     0.000000
# 50%    4601.500000     0.000000     0.000000     0.000000     0.000000
# 75%    6821.250000     0.000000     1.000000     0.000000     1.000000
# max    9059.000000     1.000000     1.000000     1.000000     1.000000
#
#               cat5         cat6         cat7         cat8         cat9  ...  \
# count  2832.000000  2832.000000  2832.000000  2832.000000  2832.000000  ...
# mean      0.355932     0.311088     0.028955     0.064266     0.402895  ...
# std       0.478879     0.463020     0.167709     0.245269     0.490567  ...
# ...

# %%
x,y=data.drop("loss",axis=1),data["loss"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
import warnings
warnings.simplefilter("ignore")

# %%
lr=LinearRegression().fit(x_train,y_train)

# %%
lr.intercept_
# Out:
# -2002.3727658951889

# %%
lr.coef_
# Out:
# array([-4.02475467e-02, -3.83789284e+02,  3.06268125e+02,  4.67652574e+02,
#        -1.97528198e+02,  3.60711254e+02, -3.75833409e+01,  2.43988805e+03,
#         9.61161428e+02,  1.30854416e+02,  4.92148192e+02, -4.07747920e+01,
#         8.55949327e+02,  2.14291472e+02, -2.58608711e+02, -5.75028025e-10,
#        -1.10923952e+03,  2.29260186e+02, -1.37815081e+03,  9.11486153e+02,
#         6.59161754e+01,  9.15622360e+02, -9.95896698e-11, -4.47677530e+03,
#        -4.78973117e+03, -4.48992658e+03, -4.34381662e+03, -4.22033514e+03,
#        -5.10563289e+03, -4.91765151e+03, -5.11738632e+03, -4.94390631e+03,
#        -5.32548813e+03, -5.35186745e+03, -1.48623383e+03, -7.29315787e+03,
#         5.82070570e+01,  2.44293656e+02,  5.34106330e+02, -6.06124916e+01,
#         1.38648806e+02, -5.39637281e+02,  8.97195209e+02,  5.30762697e+02,
#         9.32386246e+02, -2.07794769e+02,  1.21844108e+03, -7.91703077e+02,
# ...

# %%
ypred=lr.predict(x_test)

# %%
ypred
# Out:
# array([ 2290.84047545,  1919.47425324,  2664.94792771, 11655.23613832,
#         -378.76268643,  7634.29141026,  1555.47456283,  2836.8627431 ,
#         2500.47283013,  9281.12314248,  2986.5199822 ,  4205.4660754 ,
#         1809.02117768,  2313.56916144,  3812.58834697,  1856.24358278,
#         1784.19147123,  6970.27870683,  2273.41505636,  5577.50149923,
#         3664.3733175 ,  1285.42882253,  1927.68956413,  3542.22977771,
#         1711.97065767,  1397.78114749,  2185.46242152,  1974.04090036,
#         2638.2546876 ,  1683.77485515,  2263.14503398,  6233.23265028,
#         2176.55772829,  4212.52950411,   209.72892708,  3693.29916214,
#         1670.31461662,  1895.07854244,  4816.93890033,  1209.86683724,
#         3933.27741747,  3793.1871874 ,  6332.25510542,  2036.48654239,
#         5838.18659884,  3842.70404929,  4188.90786952,  4601.63529097,
#         2679.65019638,  2280.97020352,  4075.39513376,  4985.0033556 ,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,ypred)

# %%
lr.score(x,y)
# Out:
# 0.520582960773416

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test,ypred))
# Out:
# 4371281.6248067785

# %% [markdown]
# ####**FINDINGS**

# %%
#HERE WHILE PREDICTING USING LINEAR REGRESSION IT GENERATED A VERY LARGE ERROR AND PERFORMANCE IS POOR WITH LOWER ACCURACY
